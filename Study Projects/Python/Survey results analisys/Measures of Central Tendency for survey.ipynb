# %% [markdown]
# <a href="https://colab.research.google.com/github/MaidanchukIrina/Portfolio/blob/main/Measures%20of%20Central%20Tendency%20for%20survey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# vfxcv

# %%
import pandas as pd
import numpy as np
public=pd.read_csv(r'C:\\Users\\User\\OneDrive\\Desktop\\survey_results_public.csv')
pd.set_option('display.max_columns',None)

# %%
public.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
schema=pd.read_csv(r'C:\Users\User\Downloads\stack-overflow-developer-survey-2023\survey_results_schema.csv')

# %%
schema.head()
# Out:
#       qid     qname                                           question  \
# 0   QID16        S0  <div><span style="font-size:19px;"><strong>Hel...
# 1   QID12  MetaInfo                                  Browser Meta Info
# 2  QID310      Q310  <div><span style="font-size:19px;"><strong>You...
# 3  QID312      Q120
# 4    QID1        S1  <span style="font-size:22px; font-family: aria...
#
#   force_resp  type selector
# 0      False    DB       TB
# 1      False  Meta  Browser
# 2      False    DB       TB
# 3       True    MC     SAVR
# 4      False    DB       TB

# %%
public.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           89184 non-null  int64
#  1   Q120                                 89184 non-null  object
#  2   MainBranch                           89184 non-null  object
#  3   Age                                  89184 non-null  object
#  4   Employment                           87898 non-null  object
#  5   RemoteWork                           73810 non-null  object
#  6   CodingActivities                     73764 non-null  object
#  7   EdLevel                              87973 non-null  object
#  8   LearnCode                            87663 non-null  object
#  9   LearnCodeOnline                      70084 non-null  object
#  10  LearnCodeCoursesCert                 37076 non-null  object
# ...

# %%
schema.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   qid         78 non-null     object
#  1   qname       78 non-null     object
#  2   question    78 non-null     object
#  3   force_resp  67 non-null     object
#  4   type        78 non-null     object
#  5   selector    78 non-null     object
# dtypes: object(6)
# memory usage: 3.8+ KB

# %% [markdown]
# 1. Скільки респондентів пройшли опитування?

# %%
df.ResponseId.nunique()
# Out:
# 89184

# %% [markdown]
# 2. Скільки респондентів відповіли на всі запитання?

# %%
respondents_all_answers=df.dropna().shape[0]
print(respondents_all_answers)
# Out:
# 0

# %% [markdown]
# Які значення мір центральної тенденції для досвіду (WorkExp) респондентів?

# %%
mean_work_ex = df['WorkExp'].mean()
print(mean_work_ex)
# Out:
# 11.405126322311204

# %%
median_work_ex=df['WorkExp'].median()
print(median_work_ex)
# Out:
# 9.0

# %%
mode_work_ex=df['WorkExp'].mode()
print(mode_work_ex)
# Out:
# 0    5.0
# Name: WorkExp, dtype: float64

# %%
WorkEx=df.groupby('WorkExp')['ResponseId'].agg(['count', 'std','median','min', 'max'])
print(WorkEx)
# Out:
#          count           std   median    min    max
# WorkExp
# 0.0        261  26407.864709  54979.0    624  88618
# 1.0       2271  26582.126379  49270.0    208  89105
# 2.0       2796  26570.825621  46500.0     41  89175
# 3.0       2781  26582.806785  46711.0     11  89167
# 4.0       2529  26070.584613  43707.0      7  89110
# 5.0       3299  25563.888306  42251.0      8  89161
# 6.0       2329  25688.971440  40950.0      5  89164
# 7.0       2422  24539.722541  38997.0      4  89149
# 8.0       2232  24406.149859  40569.5    212  89176
# 9.0       1425  24516.953930  38728.0     13  89172
# 10.0      3019  24397.067385  38929.0      2  89141
# 11.0      1321  24055.736097  39066.0    130  89142
# 12.0      1719  23505.469460  39629.0     57  89178
# 13.0      1174  23942.262878  36520.0     35  89125
# 14.0       853  23749.814469  38655.0     20  89184
# 15.0      2001  23826.866016  39331.0     16  89174
# 16.0       875  23762.418568  38668.0    140  88724
# ...

# %% [markdown]
# 4. Скільки респондентів працює віддалено?
#
#
# Який відсоток респондентів програмує на Python?
# Скільки респондентів навчалося програмувати за допомогою онлайн курсів?
# Серед респондентів що програмують на Python в групуванні по країнам, яка середня та медіанна сума компенсації (ConvertedCompYearly) в кожній країні?
# Які рівні освіти мають 5 респондентів з найбільшою компенсацією?

# %%
df.RemoteWork.nunique()
# Out:
# 3

# %% [markdown]
# 5. Який відсоток респондентів програмує на Python?

# %%
df.programming_python_users=df.LanguageHaveWorkedWith.str.contains('Python',case=False)
Percent_python_users=df.programming_python_users.sum()/df.ResponseId.nunique()*100
print (Percent_python_users)
# Out:
# 48.392088266953714

# %% [markdown]
# 6. Скільки респондентів навчалося програмувати за допомогою онлайн курсів?

# %%
learned_online_users=df.LearnCodeOnline.str.contains('online',case=False).sum()
print(learned_online_users)
# Out:
# 46825

# %% [markdown]
# 7. Серед респондентів що програмують на Python в групуванні по країнам, яка середня та медіанна сума компенсації (ConvertedCompYearly) в кожній країні?

# %%
programming_python_users=df.LanguageHaveWorkedWith.str.contains('Python',case=False)
converted_comp_yearly_info=df.groupby(['Country','programming_python_users'])['ConvertedCompYearly'].agg(['mean','median'])
print(converted_comp_yearly_info)
# Out:
#                                               mean   median
# Country     programming_python_users
# Afghanistan False                     1.841734e+06   1144.0
#             True                      6.650000e+02     48.0
# Albania     False                     2.962307e+04   8685.0
#             True                      2.800860e+04  11844.0
# Algeria     False                     1.136883e+04   9391.0
# ...                                            ...      ...
# Yemen       True                      8.373000e+03   9000.0
# Zambia      False                     1.426071e+04   9687.0
#             True                      1.305100e+04   9687.0
# Zimbabwe    False                     3.580000e+04  15000.0
#             True                      5.600000e+03   6000.0
#
# [348 rows x 2 columns]

# %% [markdown]
# 8. Які рівні освіти мають 5 респондентів з найбільшою компенсацією?

# %%
sorted_df=df.sort_values(by='ConvertedCompYearly', ascending=False)
result=sorted_df.head()[['ConvertedCompYearly','EdLevel']]
print(result)
# Out:
#        ConvertedCompYearly                                         EdLevel
# 53268           74351432.0  Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 77848           73607918.0  Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 66223           72714292.0    Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 28121           57513831.0                       Primary/elementary school
# 19679           36573181.0  Professional degree (JD, MD, Ph.D, Ed.D, etc.)
